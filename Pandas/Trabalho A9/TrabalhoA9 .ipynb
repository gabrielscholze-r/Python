# %%
import math

import numpy as np
import pandas as pd

pd.set_option("max_columns", None)
pd.set_option("max_rows", None)


while True:
    try:
        arquivo = pd.read_csv("user-languages.csv", sep=",")

    except:
        print("Não é possivel carregar a base de dados!")
        break

        # print(arquivo)

    menu = int(
        input(
            "\n --Menu de Opções--"
            "\n Visualizar linguagem python = 1"
            "\n Sair = 2"
            "\nDigite a opção: "
        )
    )

    # --------------------------------------------------------------------------------
    if menu == 1:
        y = arquivo["python"]  # filtra apenas os resultados da coluna python

        # print(y)
        lista = arquivo["python"].unique()

        counter1=0
        for l in lista:
            if l>=0.00 and l<0.06:
                counter1+=1
                counter2=0
        for l in lista:
            if l>=0.06 and l<0.12:
                counter2+=1
                counter3=0
        for l in lista:
            if l>=0.12 and l<0.18:
                counter3+=1
                counter4=0
        for l in lista:
            if l>=0.18 and l<0.24:
                counter4+=1
                counter5=0
        for l in lista:
            if l>=0.24 and l<0.30:
                counter5+=1
                counter6=0
        for l in lista:
            if l>=0.30 and l<0.36:
                counter6+=1
                counter7=0
        for l in lista:
            if l>=0.36 and l<0.42:
                counter7+=1
                counter8=0
        for l in lista:
            if l>=0.42 and l<0.48:
                counter8+=1
                counter9=0
        for l in lista:
            if l>=0.48 and l<0.54:
                counter9+=1
                counter10=0
        for l in lista:
            if l>=0.54 and l<0.60:
                counter10+=1
                counter11=0
        for l in lista:
            if l>=0.60 and l<0.66:
                counter11+=1
                counter12=0
        for l in lista:
            if l>=0.66 and l<0.72:
                counter12+=1
                counter13=0
        for l in lista:
            if l>=0.72 and l<0.78:
                counter13+=1
                counter14=0
        for l in lista:
            if l>=0.78 and l<0.84:
                counter14+=1
                counter15=0
        for l in lista:
            if l>=0.84 and l<0.90:
                counter15+=1

        print("")
        print("---------------- TABELA ----------------")
        print("1 -> fi: ", counter1, '|  Xi:', 0.03,' |  Fi:', counter1)
        print("2 -> fi: ", counter2, '|  Xi:',0.09,' |  Fi:', counter1 + counter2)
        print("3 -> fi: ", counter3, ' |  Xi:', 0.15, ' |  Fi:', counter1+counter2+counter3)
        print("4 -> fi: ", counter4, ' |  Xi:', 0.21,' |  Fi:', counter1+counter2+counter3+counter4)
        print("5 -> fi: ", counter5, ' |  Xi:', 0.27,' |  Fi:', counter1+counter2+counter3+counter4+counter5)
        print("6 -> fi: ", counter6, ' |  Xi:', 0.33,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6)
        print("7 -> fi: ", counter7, '  |  Xi:', 0.39,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7)
        print("8 -> fi: ", counter8, '  |  Xi:', 0.45,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8)
        print("9 -> fi: ", counter9, '  |  Xi:', 0.51,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9)
        print("10 -> fi: ", counter10, '  |  Xi:', 0.57,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10)
        print("11 -> fi: ", counter11, ' |  Xi:', 0.63,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10+counter11)
        print("12 -> fi: ", counter12, '  |  Xi:', 0.69,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10+counter11+counter12)
        print("13 -> fi: ", counter13, '  |  Xi:', 0.75,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10+counter11+counter12+counter13)
        print("14 -> fi: ", counter14, '  |  Xi:', 0.81,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10+counter11+counter12+counter13+counter14)
        print("15 -> fi: ", counter15, '  |  Xi:', 0.97,' |  Fi:', counter1+counter2+counter3+counter4+counter5+counter6+counter7+counter8+counter9+counter10+counter11+counter12+counter13+counter14+counter15)
        print("-" * 40)

        print("Lista:", lista)

        # numero minimo e maximo
        num_menor = lista.min()
        num_maior = lista.max()

        print("")
        print("Menor valor presente:", num_menor)
        print("Maior valor presente:", num_maior)
        print("")

        # --------------------------------------------------------------------------------

        # amplitude da classe
        amplitude = num_maior - num_menor
        print("Amplitude:", amplitude)
        print("")

        # --------------------------------------------------------------------------------

        # quantidade de numeros
        qtd = arquivo["python"].count()  # quantidade de numeros
        print("A quantidade de números na coluna 'Python' é:", qtd)
        print("")

        # --------------------------------------------------------------------------------

        #
        qtdclasses = 1 + 3.3 * math.log(qtd, 10)
        print("A quantidade de classes presentes é de: ", qtdclasses)
        print("")

        # --------------------------------------------------------------------------------

        # Amplitude da classe python
        amplitudedaclasse = amplitude / qtdclasses
        print("Amplitude da classe: ", amplitudedaclasse)
        print("")

    # --------------------------------------------------------------------------------

    # print(y)

    elif menu == 2:
        print("Saindo...")
        break
# Out:
#  --Menu de Opções--
#  Visualizar linguagem python = 1
#  Sair = 2
# Digite a opção:  1
# ---------------- TABELA ----------------
# 1 -> fi:  3777 |  Xi: 0.03  |  Fi: 3777
# 2 -> fi:  1216 |  Xi: 0.09  |  Fi: 4993
# 3 -> fi:  665  |  Xi: 0.15  |  Fi: 5658
# 4 -> fi:  489  |  Xi: 0.21  |  Fi: 6147
# 5 -> fi:  310  |  Xi: 0.27  |  Fi: 6457
# 6 -> fi:  161  |  Xi: 0.33  |  Fi: 6618
# 7 -> fi:  82   |  Xi: 0.39  |  Fi: 6700
# 8 -> fi:  45   |  Xi: 0.45  |  Fi: 6745
# 9 -> fi:  24   |  Xi: 0.51  |  Fi: 6769
# 10 -> fi:  5   |  Xi: 0.57  |  Fi: 6774
# 11 -> fi:  13  |  Xi: 0.63  |  Fi: 6787
# 12 -> fi:  5   |  Xi: 0.69  |  Fi: 6792
# 13 -> fi:  3   |  Xi: 0.75  |  Fi: 6795
# 14 -> fi:  1   |  Xi: 0.81  |  Fi: 6796
# 15 -> fi:  0   |  Xi: 0.97  |  Fi: 6796
# ----------------------------------------
# Lista: [0.0105364  0.02899628 0.18510858 ... 0.09939759 0.01290963 0.11541219]
#
# Menor valor presente: 0.0
# Maior valor presente: 1.0
#
# Amplitude: 1.0
#
# ...
