# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-292f82be1b7a> in <module>
# ----> 1 from google.colab import files
#       2
#       3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# ModuleNotFoundError: No module named 'google'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
df = pd.DataFrame()
display = pd.read_csv("database2.csv")
r_df = display.drop(labels = list(range(17361)))
#display = r_df.drop(columns=["go", "haskell", "objective-c", "swift", "ruby", "html", "c", "c#", "css", "javascript", "php", "powershell", "sql"])
display = r_df

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
#df["A"] = pd.Series([0, 1])
#df.plot(x="A", y="B");
df.plot.line();

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
df.plot.area();

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
df.plot.bar();

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
df.plot.hist();

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
df.plot.scatter(x ="python", y ="c++");
df.plot.scatter(x ="java", y = "c++");

# %%
df = pd.DataFrame(display, columns=["python", "java", "c++"])
df.plot.box();

# %%
df["python"].value_counts().plot.pie()

plt.show()
